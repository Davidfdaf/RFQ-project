# %% [markdown]
# ## Usual imports

# %%
import pandas as pd
import numpy as np
import sys, math, os, json, re, random
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from sklearn.metrics import accuracy_score
from sklearn.metrics import log_loss

from reticulum import AdaptiveBayesianReticulum

# jupyter magic to display plots directly in the notebook
# %matplotlib inline

# use vector graphics format for nicer plots
# %config Inline.Backend.figure_format = 'svg'

# %config Completer.use_jedi = False

# %load_ext autoreload
# %autoreload 2

# %%
DATA = 'data/RfqData.xlsx'

# %%
sheets = pd.ExcelFile(DATA).sheet_names
sheets
# Out:
# ['Training RFQs', 'OOS RFQs', 'Competition RFQs']

# %%
training = pd.read_excel(DATA, sheet_name=sheets[0])
test = pd.read_excel(DATA, sheet_name=sheets[1])
competition = pd.read_excel(DATA, sheet_name=sheets[2])

# %%
training.head()
# Out:
#     Time    Bond   Side  Notional Counterparty  MidPrice  QuotedPrice  \
# 0  25000  Bond_2  Offer  10000000       Ctpy_0    124.01       124.25
# 1  25001  Bond_0    Bid      1000       Ctpy_1     98.07        98.06
# 2  25002  Bond_1  Offer      1000       Ctpy_1    170.30       170.40
# 3  25003  Bond_0    Bid     20000       Ctpy_0     98.00        97.98
# 4  25004  Bond_1  Offer      1000       Ctpy_3    171.12       171.16
#
#    Competitors  Traded  NextMidPrice
# 0            1  MISSED        124.24
# 1            1    DONE         98.08
# 2            1  MISSED        170.64
# 3            4    DONE         97.94
# 4            2    DONE        171.46

# %%
competition
# Out:
#     Time    Bond   Side  Notional Counterparty  MidPrice  QuotedPrice  \
# 0  31000  Bond_0    Bid      1000       Ctpy_0     82.55          NaN
# 1  31001  Bond_2    Bid      1000       Ctpy_3    110.32          NaN
# 2  31004  Bond_1  Offer    300000       Ctpy_0    126.83          NaN
# 3  31008  Bond_0    Bid      1000       Ctpy_1     82.28          NaN
# 4  31009  Bond_2  Offer      1000       Ctpy_1    109.99          NaN
#
#    Competitors
# 0            3
# 1            4
# 2            2
# 3            1
# 4            2

# %%
target_mapping = {'MISSED': 0, 'DONE': 1}

# %%
def add_features(df):
    df['quote_diff'] = df['QuotedPrice']/df['MidPrice']
    df['Traded'] = df['Traded'].map(target_mapping)
    # df['Competitors'] = df['Competitors'].apply(lambda x: str(x))
    df['Notional_cuts'] = pd.cut(df['Notional'], [0, 100000, 1000000, 10000000, 50000000], labels=[0, 1, 2, 3], include_lowest=True, right=True)
    
    cols = ['Side']
    one_hot_encode = pd.get_dummies(df[cols])
    df = df.join(one_hot_encode)
    
    cols_to_drop = ['Bond', 'Side', 'Counterparty', 'Time'] + ['Notional', 'QuotedPrice', 'MidPrice', 'NextMidPrice']
    
    return df.drop(columns=cols_to_drop)

# %%
len(training.Notional)
# Out:
# 5000

# %%
training = add_features(training)
training.head()
# Out:
#    Competitors  Traded  quote_diff Notional_cuts  Side_Bid  Side_Offer
# 0            1       0    1.001935             2         0           1
# 1            1       1    0.999898             0         1           0
# 2            1       0    1.000587             0         0           1
# 3            4       1    0.999796             0         1           0
# 4            2       1    1.000234             0         0           1

# %%
test = add_features(test)

test.head()
# Out:
#    Competitors  Traded  quote_diff Notional_cuts  Side_Bid  Side_Offer
# 0            2       0    0.997135             1         1           0
# 1            3       1    0.999646             0         1           0
# 2            4       1    0.999882             0         1           0
# 3            1       1    0.999540             0         1           0
# 4            2       1    1.000473             2         0           1

# %%
# extract input and target
X_train = training.drop(columns=['Traded']).values
y_train = training[['Traded']].values.ravel()
X_test = test.drop(columns=['Traded']).values
y_test = test[['Traded']].values.ravel()

# %%
# train model
model = AdaptiveBayesianReticulum(
    prior=(1, 1),
    pruning_factor=1.01,
    n_iter=100,
    learning_rate_init=0.1,
    n_gradient_descent_steps=1,
    initial_relative_stiffness=20)

t0 = dt.datetime.utcnow()
model.fit(X_train, y_train, verbose=True)
t1 = dt.datetime.utcnow()

print('Model:')
print(model)
print(f'Training took {t1-t0}')
# Out:
# Creating root node at level=0, n_data=5000
# Splitting left  child of node at level=0, n_data=5000.00
# Splitting left  child of node at level=1, n_data=4520.11
# Splitting right child of node at level=0, n_data=5000.00
# Splitting right child of node at level=2, n_data=3784.65
# Pruning node at level 3
# Splitting right child of node at level=2, n_data=3784.65
# Splitting left  child of node at level=2, n_data=3784.65
# Splitting left  child of node at level=3, n_data=2578.26
# Splitting right child of node at level=4, n_data=601.90
# Splitting left  child of node at level=5, n_data=302.32
# Pruning node at level 6
# Splitting left  child of node at level=1, n_data=479.89
# Splitting right child of node at level=1, n_data=479.89
# Splitting right child of node at level=3, n_data=2578.26
# Splitting left  child of node at level=3, n_data=1206.38
# Splitting right child of node at level=5, n_data=302.32
# Splitting left  child of node at level=4, n_data=1976.36
# Splitting right child of node at level=1, n_data=4520.11
# Splitting left  child of node at level=4, n_data=601.90
# Splitting right child of node at level=5, n_data=1535.64
# Splitting right child of node at level=4, n_data=715.40
# Splitting right child of node at level=2, n_data=735.47
# Splitting left  child of node at level=6, n_data=879.38
# Splitting right child of node at level=3, n_data=1206.38
# Splitting right child of node at level=7, n_data=319.12
# Pruning node at level 8
# Splitting right child of node at level=5, n_data=299.59
# Pruning node at level 6
# Splitting left  child of node at level=5, n_data=1535.64
# Splitting right child of node at level=6, n_data=879.38
# Splitting left  child of node at level=2, n_data=735.47
# Splitting left  child of node at level=7, n_data=560.26
# Pruning node at level 8
# Splitting left  child of node at level=5, n_data=302.32
# Pruning node at level 6
# Splitting right child of node at level=6, n_data=179.76
# Pruning node at level 7
# Splitting right child of node at level=3, n_data=491.75
# Splitting left  child of node at level=5, n_data=302.32
# Pruning node at level 6
# Splitting left  child of node at level=5, n_data=302.32
# Pruning node at level 6
# Splitting left  child of node at level=3, n_data=491.75
# Pruning node at level 4
# Splitting left  child of node at level=6, n_data=656.26
# Splitting left  child of node at level=2, n_data=239.58
# Splitting left  child of node at level=5, n_data=299.59
# Splitting left  child of node at level=2, n_data=240.30
# Splitting left  child of node at level=7, n_data=319.12
# Splitting right child of node at level=5, n_data=299.59
# Pruning node at level 6
# Splitting right child of node at level=4, n_data=490.99
# Splitting left  child of node at level=4, n_data=715.40
# Splitting right child of node at level=6, n_data=656.26
# Splitting right child of node at level=7, n_data=319.12
# Pruning node at level 8
# Splitting left  child of node at level=3, n_data=491.75
# Pruning node at level 4
# Splitting right child of node at level=7, n_data=560.26
# Pruning node at level 8
# Splitting left  child of node at level=3, n_data=206.49
# Pruning node at level 4
# Splitting left  child of node at level=8, n_data=156.54
# Pruning node at level 9
# Splitting left  child of node at level=6, n_data=227.20
# Pruning node at level 7
# Splitting left  child of node at level=4, n_data=213.96
# Pruning node at level 5
# Splitting left  child of node at level=7, n_data=560.26
# Pruning node at level 8
# Splitting right child of node at level=5, n_data=244.62
# Splitting left  child of node at level=3, n_data=243.71
# Pruning node at level 4
# Splitting left  child of node at level=6, n_data=656.26
# Splitting right child of node at level=3, n_data=206.49
# Splitting right child of node at level=8, n_data=156.54
# Pruning node at level 9
# Splitting left  child of node at level=5, n_data=244.62
# Pruning node at level 6
# Splitting right child of node at level=7, n_data=560.26
# Pruning node at level 8
# Splitting right child of node at level=7, n_data=319.12
# Pruning node at level 8
# Splitting right child of node at level=4, n_data=213.96
# Pruning node at level 5
# Splitting left  child of node at level=4, n_data=213.96
# Pruning node at level 5
# Splitting right child of node at level=7, n_data=560.26
# Pruning node at level 8
# Splitting right child of node at level=4, n_data=1976.36
# Splitting right child of node at level=5, n_data=342.76
# Splitting left  child of node at level=5, n_data=372.64
# Splitting left  child of node at level=5, n_data=372.64
# Splitting right child of node at level=7, n_data=560.26
# Splitting left  child of node at level=2, n_data=240.30
# Splitting right child of node at level=4, n_data=197.82
# Splitting right child of node at level=2, n_data=240.30
# Pruning node at level 3
# Splitting right child of node at level=7, n_data=508.98
# Splitting left  child of node at level=5, n_data=193.30
# Pruning node at level 6
# Splitting left  child of node at level=8, n_data=156.54
# Pruning node at level 9
# Splitting left  child of node at level=5, n_data=372.64
# Splitting left  child of node at level=3, n_data=491.75
# Splitting left  child of node at level=3, n_data=243.71
# Pruning node at level 4
# Splitting right child of node at level=8, n_data=156.54
# Pruning node at level 9
# Splitting left  child of node at level=2, n_data=240.30
# Splitting left  child of node at level=5, n_data=342.76
# Pruning node at level 6
# Splitting right child of node at level=5, n_data=440.72
# Splitting left  child of node at level=2, n_data=240.30
# Splitting left  child of node at level=4, n_data=213.96
# Pruning node at level 5
# Splitting left  child of node at level=5, n_data=302.32
# Pruning node at level 6
# Splitting right child of node at level=6, n_data=227.20
# Pruning node at level 7
# Splitting right child of node at level=4, n_data=277.79
# Splitting left  child of node at level=2, n_data=240.30
# Splitting left  child of node at level=6, n_data=175.30
# Splitting left  child of node at level=5, n_data=372.64
# Splitting left  child of node at level=8, n_data=305.45
# Splitting right child of node at level=6, n_data=227.20
# Pruning node at level 7
# Splitting left  child of node at level=4, n_data=213.96
# Pruning node at level 5
# Splitting left  child of node at level=5, n_data=193.30
# Pruning node at level 6
# Splitting right child of node at level=3, n_data=243.71
# Splitting right child of node at level=8, n_data=156.54
# Splitting left  child of node at level=9, n_data=97.48
# Pruning node at level 10
# Splitting left  child of node at level=5, n_data=193.30
# Pruning node at level 6
# Splitting right child of node at level=8, n_data=304.92
# Pruning node at level 9
# │           └─ right: p(y)=[0.96191171 0.03808829], n=66.98969313992883
# └─ right:origin=[-0.00458465,  0.95495041,  0.00487978,  0.01288239, -0.03702255], normal=[ -4.29686873, 895.00819818,   4.57347818,  12.07376191, -34.69864971]
#    ├─ left: origin=[-1.34367692e-03,  9.95818489e-01, -5.49948405e-05, -4.06866867e-04,  2.45529905e-04], normal=[-1.31050798e+01,  9.71236504e+03, -5.36372815e-01, -3.96823274e+00,  2.39468948e+00]
#    │  ├─ left: origin=[ 3.42647141e-06,  9.97459373e-01, -9.24019524e-04, -5.79474772e-04, -1.13640891e-04], normal=[-5.68684118e-02, -1.65546195e+04,  1.53357541e+01,  9.61741863e+00,  1.88607351e+00]
#    │  │  ├─ left:  p(y)=[0.90623921 0.09376079], n=8.666237786243292
#    │  │  └─ right:origin=[ 5.69492274e-06,  9.98343206e-01,  1.63174166e-04,  6.18539329e-05, -1.09931387e-04], normal=[-5.24273031e-01, -9.19072028e+04, -1.50217691e+01, -5.69425616e+00,  1.01202535e+01]
#    │  │     ├─ left:  p(y)=[0.84660017 0.15339983], n=4.519462873544357
#    │  │     └─ right:origin=[-2.86884816e-05,  9.98309702e-01,  6.28487185e-05,  2.37843864e-06, -6.67818575e-05], normal=[-5.54114260e+00,  1.92822210e+05,  1.21391476e+01,  4.59392304e-01, -1.28988282e+01]
#    │  │        ├─ left:  p(y)=[0.49173512 0.50826488], n=191.0799516431718
#    │  │        └─ right: p(y)=[0.76327805 0.23672195], n=2.2244554398691596
#    │  └─ right: p(y)=[0.96867302 0.03132698], n=33.094587238513164
#    └─ right:origin=[ 3.51004755e-05,  1.00012953e+00, -9.89487764e-05,  9.14133158e-06, -8.43802076e-06], normal=[ 5.53430821e+00,  1.57690885e+05, -1.56012994e+01,  1.44131798e+00, -1.33042664e+00]
#       ├─ left:  p(y)=[0.40782995 0.59217005], n=182.7434872699717
#       └─ right: p(y)=[0.06542438 0.93457562], n=57.55753771539754
#
# Training took 0:00:00.796680

# %%
# evaluate performance
log_loss_train = log_loss(y_train, model.predict_proba(X_train))
log_loss_test = log_loss(y_test, model.predict_proba(X_test))
accuracy_train = accuracy_score(y_train, model.predict(X_train))
accuracy_test = accuracy_score(y_test, model.predict(X_test))

info_train = f'Train: Log-loss = {log_loss_train}, accuracy = {100*accuracy_train:.4f} %'
info_test = f'Test: Log-loss = {log_loss_test}, accuracy = {100*accuracy_test:.4f} %'
print(f'Depth:  {model.get_depth()}')
print(f'Leaves: {model.get_n_leaves()}')
print(info_train)
print(info_test)
print(f'Feature importance: {model.feature_importance()}')
# Out:
# Depth:  10
# Leaves: 45
# Train: Log-loss = 0.4127035604190389, accuracy = 81.9000 %
# Test: Log-loss = 0.4167728917344216, accuracy = 83.0000 %
# Feature importance: [9.07488487e-04 9.96013990e-01 5.02931510e-04 1.34847964e-03
#  1.22711042e-03]

# %% [markdown]
# ## Estimate the probability of execution a trade for a given price (and any other feature available in the data)

# %%
trade_execution_prob = model.predict_proba(X_test)[:, 1]
